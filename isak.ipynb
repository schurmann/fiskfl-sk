# %%
import pandas as pd
import numpy as np
from itertools import chain
from math import floor

# %%
total_csvs = !ls total_*

# %%
def write_excel(df: pd.DataFrame, file_name: str, sheet: str = 'Sheet1'):
    writer = pd.ExcelWriter(f'{file_name}.xlsx')
    df.to_excel(writer, sheet)
    writer.save()

def read_csv(file_name: str, **args: dict) -> pd.DataFrame:
    return pd.read_csv(filepath_or_buffer=file_name, **args)


def file_name_suffix(name: str) -> str:
    return name[name.rfind('_') + 1:-4]

total_names = ['fuel', 'co2']
df_totals = [(file_name_suffix(name),
              read_csv(
                  file_name=name,
                  encoding='utf-8',
                  names=total_names,
                  header=0)) for name in total_csvs]
df_new_co2 = read_csv(
    file_name='fordonspark.csv',
    encoding='utf-8',
    header=0,
    names=['license_nbr', 'co2'])
df_cars = pd.read_csv(
    'cars.csv',
    encoding='latin1',
    sep=';',
    header=0,
    names=[
        'license_nbr', 'brand', 'year', 'driver', 'region', 'consumption',
        'co2', 'fuel'
    ])

# %%
df_cars['brand'] = df_cars['brand'].apply(lambda b: ' '.join(b.upper().split(' ')[:2]))
df_cars['co2'] = df_new_co2['co2']
df_cars.head()
# Out:
#   license_nbr           brand  year                driver region consumption  \
# 0     YZF 336  VW TRANSPORTER  2018       ALBIN LÖFSTRAND    ÖST        0,62
# 1     PYN 113     MB SPRINTER  2018  ALEXANDER WERNERSSON    SYD        0,81
# 2     JUB 435  VW TRANSPORTER  2016      ANDERS ANDERSSON    SYD        0,77
# 3     YLJ 847     MB SPRINTER  2017        ANDERS BONNIER    SYD        0,81
# 4     YHN 351         AUDI Q5  2017       ANDERS KARLSSON    ÖST        0,59
#
#      co2    fuel
# 0  36464  Diesel
# 1  45974  Diesel
# 2  44114  Diesel
# 3  45974  Diesel
# 4  18098  Diesel

# %%
print(df_totals[0][0])
df_totals[0][1].head()
# Out:
# big
#                                             fuel    co2
# 0                           Konventionell diesel  45530
# 1  Biodiesel B25.5 (25% inblandning av FAME/HVO)  37334
# 2                                      Gasfordon  26009

# %%
print(df_totals[1][0])
df_totals[1][1].head()
# Out:
# medium
#                                             fuel    co2
# 0                           Konventionell diesel  36418
# 1  Biodiesel B25.5 (25% inblandning av FAME/HVO)  32744
# 2                           Konventionell bensin  37787
# 3           Biobensin E4.8 (4.8% bioinblandning)  34988

# %%
print(df_totals[2][0])
df_totals[2][1].head()
# Out:
# small
#                                             fuel    co2
# 0                           Konventionell diesel  27742
# 1  Biodiesel B25.5 (25% inblandning av FAME/HVO)  23182
# 2                           Konventionell bensin  32822
# 3           Biobensin E4.8 (4.8% bioinblandning)  29587
# 4                        Elfordon skåp. 26.7 kWh  13543

# %%
# Find best fuel value for every category
def find_opt_co2(totals):
    cat_co2_dict = {}
    co2_fuel_dict = {}
    for cat, df in totals:
        min_idx = df['co2'].idxmin()
        fuel, co2 = df.iloc[min_idx, 0], df.iloc[min_idx, 1]
        cat_co2_dict[cat] = co2
        co2_fuel_dict[co2] = fuel
    return cat_co2_dict, co2_fuel_dict


cat_co2_dict, co2_fuel_dict = find_opt_co2(df_totals)

# %%
car_cats = {
    'service': {
        'small': set(['VW CADDY']),
        'medium': set(['MB VITO', 'VW TRANSPORTER']),
        'big': set(['MB SPRINTER', 'VW TRANSPORT'])
    },
    'work':
    set([
        'AUDI A6', 'AUDI Q5', 'BMW 220D', 'BMW 318D', 'BMW 320D',
        'SKODA SUPERB', 'VOLVO S60', 'VOLVO S90', 'VOLVO V60', 'VOLVO V90',
        'VOLVO XC40', 'VOLVO XC60', 'VOLVO XC70', 'VW PASSAT', 'VW TIGUAN',
        'VW TOUAREG'
    ])
}

service_brands = set(chain(*car_cats['service'].values()))
work_brands = car_cats['work']

def get_car_cat(brand):
    if brand in work_brands:
        return 'work'
    for k, v in car_cats['service'].items():
        if brand in v:
            return k
    raise Exception(f'Could not classify brand {brand}')

# %%
# Assign new column 'category' and filter cars
df_cars = df_cars.assign(category=[get_car_cat(brand) for brand in df_cars['brand']])
df_filtered = df_cars.query("(brand in @service_brands & year < 2015) | (brand in @work_brands & year < 2017)")

# %%
# Treat 25% of big service cars as medium
sorted_big = df_filtered.query("category == 'big' & (region == 'ÖST' | region == 'SYD' | region == 'VÄST')").sort_values('co2', ascending=False)
top_25_big = sorted_big.iloc[:floor(len(sorted_big) * 0.25)]
df_replaced_big = df_filtered.copy()
df_replaced_big.loc[top_25_big.index.values.tolist(), 'category'] = 'medium'

# %%
# Assign new column 'new_co2'
df_replaced_big = df_replaced_big.assign(new_co2=[cat_co2_dict[cat] for cat in df_filtered['category']])

# %%
df_replaced_big.loc[top_25_big.index.values.tolist(), 'category'] = 'big' # Show the 25% cars as big again
df_scen1 = df_cars.copy()
df_scen1['new_co2'] = np.nan
df_scen1.update(df_replaced_big)
df_scen1 = df_scen1.assign(new_fuel=[co2_fuel_dict.get(co2, np.nan) for co2 in df_scen1['new_co2']])

# %%
df_scen1
# Out:
#     license_nbr           brand    year                            driver  \
# 0       YZF 336  VW TRANSPORTER  2018.0                   ALBIN LÖFSTRAND
# 1       PYN 113     MB SPRINTER  2018.0              ALEXANDER WERNERSSON
# 2       JUB 435  VW TRANSPORTER  2016.0                  ANDERS ANDERSSON
# 3       YLJ 847     MB SPRINTER  2017.0                    ANDERS BONNIER
# 4       YHN 351         AUDI Q5  2017.0                   ANDERS KARLSSON
# 5       BAP 210        VW CADDY  2017.0                    ANDERS NILSSON
# 6       RSA 761    VW TRANSPORT  2015.0                  ANDREAS ENGSTRÖM
# 7       YHR 669        BMW 320D  2016.0                   ANDREAS FRITZON
# 8       EFM 275        BMW 320D  2017.0               ANDREAS KNUTSEN-ÖY
# 9       ELW 214    VW TRANSPORT  2016.0                      ANDREAS LÖÖV
# 10      LXL 304    VW TRANSPORT  2012.0                  ANDREAS SVENSSON
# 11      CCO 411    VW TRANSPORT  2016.0                  ANDREAS TAGESSON
# 12      YOU 925         AUDI A6  2018.0                        ANNA OLSÉN
# 13      CJJ 645    VW TRANSPORT  2016.0                     ANTON LINDAHL
# 14      YZH 793    VW TRANSPORT  2018.0                       ARI HARJULA
# 15      ENC 746       VW PASSAT  2015.0                   AULIS GÅRDEMARK
# 16      YYL 602  VW TRANSPORTER  2018.0                  BASHAR ALGAILANI
# 17      NRR 764        VW CADDY  2009.0                 BEG-CENTER ÖREBRO
# 18      EDD 689  VW TRANSPORTER  2014.0                   BENGT BERGSTRÖM
# 19      MBM 295    VW TRANSPORT  2012.0                     BENNY OLANDER
# 20      OSF 296  VW TRANSPORTER  2014.0                    BILLY GRANBERG
# 21      PYT 177    VW TRANSPORT  2012.0                     BJÖRN PERSSON
# 22      PXA 837     MB SPRINTER  2013.0                  CHRISTER LARSSON
# 23      SPO 579  VW TRANSPORTER  2013.0                 CHRISTIAN SANDHÉN
# 24      ZDG 643    VW TRANSPORT  2018.0             CHRISTOFFER DANDANELL
# 25      YAJ 341      VOLVO XC60  2015.0             CHRISTOFFER JANNESSON
# 26      YLJ 848     MB SPRINTER  2017.0                 CHRISTOFFER STEEN
# 27      MEH 907     MB SPRINTER  2012.0                     CLAES WINGREN
# 28      JWP 114         MB VITO  2015.0                       CONNY GRAHN
# 29      MLU 460      VOLVO XC40  2018.0                      DAN JONASSON
# ..          ...             ...     ...                               ...
# 252     YXT 676       VOLVO V60  2018.0                    THOMAS EDSTRÖM
# 253     HHN 846      VW TOUAREG  2018.0                     THOMAS HASCHE
# 254     PZG 035    VW TRANSPORT  2017.0                     THOMAS KNUTER
# 255     YLK 178  VW TRANSPORTER  2017.0                     TOBIAS JENSEN
# 256     APF 478     MB SPRINTER  2014.0                  TOBIAS PETERSSON
# 257     PEY 536  VW TRANSPORTER  2017.0                      TOM SÖRENSEN
# 258     NKW 765        VW CADDY  2014.0                    TOMAS ARONSSON
# 259     JMD 187     MB SPRINTER  2014.0                    TOMAS CARLSSON
# 260     JFH 066     MB SPRINTER  2018.0                     TOMAS PERSSON
# 261     GOY 021        VW CADDY  2013.0                     TOMAS ÅKESSON
# 262     PFZ 985      VOLVO XC60  2017.0                         TOMM HOLM
# 263     ZDE 122     MB SPRINTER  2018.0                      TOMMY HANSEN
# 264     UUS 364  VW TRANSPORTER  2014.0                        TOMMY ROVA
# 265     GOA 490    VW TRANSPORT  2013.0                    TOMMY SVENSSON
# 266     HOH 068         MB VITO  2012.0                  TONIE ARTHURSSON
# 267     MSF 003     MB SPRINTER  2013.0                      TONY OHLSSON
# 268     NBA 820    VW TRANSPORT  2015.0                 TORBJÖRN CARLSSON
# 269     NWJ 120         MB VITO  2013.0                  TORBJÖRN OLANDER
# 270     YKS 258      VOLVO XC60  2017.0                     TORE MATTSSON
# 271     PNU 681  VW TRANSPORTER  2014.0                    TORGNY AHLSTEN
# 272     JSH 364    VW TRANSPORT  2009.0     UDDEHOLM, HAGFORS 1 (OLA ASP)
# 273     CNN 077         MB VITO  2008.0  UDDEHOLM, HAGFORS 2 (J Emilsson)
# 274     EYP 932       VOLVO V90  2017.0                    ULF PETTERSSON
# 275     YYL 598  VW TRANSPORTER  2018.0                     URBAN JONSSON
# 276     ACC 598     MB SPRINTER  2011.0      VCC Olofström (J-Å Sjöstedt)
# 277     GTU 734        VW CADDY  2008.0      VCC Olofström (J-Å Sjöstedt)
# 278     HCU 385  VW TRANSPORTER  2015.0           VERKSTADSBIL ROSERSBERG
# 279     MWS 882     MB SPRINTER  2014.0                  VICTOR HÅKANSSON
# 280     KZC 239         MB VITO  2010.0    VPT 1, SKÖVDE (TOMAS ARONSSON)
# 281     MEJ 398         MB VITO  2012.0      VPT, SKÖVDE (TOMAS ARONSSON)
#
#        region consumption      co2    fuel category  new_co2  \
# 0         ÖST        0,62  36464.0  Diesel   medium      NaN
# 1         SYD        0,81  45974.0  Diesel      big      NaN
# 2         SYD        0,77  44114.0  Diesel   medium      NaN
# 3         SYD        0,81  45974.0  Diesel      big      NaN
# 4         ÖST        0,59  18098.0  Diesel     work      NaN
# 5         SYD        0,50  31034.0  Diesel    small      NaN
# 6         ÖST        0,84  47444.0  Diesel      big      NaN
# 7        MITT        0,47  15866.0  Diesel     work  10126.0
# 8        MITT        0,44  15278.0  Diesel     work      NaN
# 9        MITT        0,84  47444.0  Diesel      big      NaN
# 10       MITT        0,86  48374.0  Diesel      big  26009.0
# 11        ÖST        0,84  47444.0  Diesel      big      NaN
# 12   CENTRALT        0,45  15434.0  Diesel     work      NaN
# 13       MITT        0,81  45974.0  Diesel      big      NaN
# 14        ÖST        0,50  30884.0  Diesel      big      NaN
# 15   CENTRALT        0,41  14630.0  Diesel     work  10126.0
# 16        ÖST        0,62  36464.0  Diesel   medium      NaN
# 17   CENTRALT        0,62  36914.0  Diesel    small  13543.0
# 18   CENTRALT        0,75  43184.0  Diesel   medium  32744.0
# 19       VÄST        0,86  48374.0  Diesel      big  26009.0
# 20       MITT        0,81  46124.0  Diesel   medium  32744.0
# 21       MITT        0,86  48374.0  Diesel      big  26009.0
# 22        SYD        0,82  46664.0  Diesel      big  26009.0
# 23        ÖST        0,82  46514.0  Diesel   medium  32744.0
# 24        ÖST        0,77  43964.0  Diesel      big      NaN
# 25       VÄST        0,57  17726.0  Diesel     work  10126.0
# 26        SYD        0,81  45974.0  Diesel      big      NaN
# 27        SYD        0,82  46664.0  Diesel      big  26009.0
# 28       MITT        0,66  38624.0  Diesel   medium      NaN
# 29       VÄST        0,50  16514.0  Diesel     work      NaN
# ..        ...         ...      ...     ...      ...      ...
# 252       SYD        0,57  17726.0  Diesel     work      NaN
# 253  CENTRALT        0,67  19706.0  Diesel     work      NaN
# 254       ÖST        0,50  31034.0  Diesel      big      NaN
# 255       SYD        0,62  36464.0  Diesel   medium      NaN
# 256       SYD        0,80  45434.0  Diesel      big  26009.0
# 257       ÖST        0,62  36464.0  Diesel   medium      NaN
# 258      MITT        0,57  34214.0  Diesel    small  13543.0
# 259      VÄST        0,80  45434.0  Diesel      big  26009.0
# 260      MITT        0,80  45284.0  Diesel      big      NaN
# 261       ÖST        0,57  34214.0  Diesel    small  13543.0
# 262      MITT        0,57  17726.0  Diesel     work      NaN
# 263       SYD        0,82  46514.0  Diesel      big      NaN
# 264       ÖST        0,82  46514.0  Diesel   medium  32744.0
# 265      MITT        0,81  45974.0  Diesel      big  26009.0
# 266      MITT        0,75  43184.0  Diesel   medium  32744.0
# 267      MITT        0,82  46664.0  Diesel      big  26009.0
# 268       ÖST        0,84  47444.0  Diesel      big      NaN
# 269      MITT        0,82  46514.0  Diesel   medium  32744.0
# 270       ÖST        0,57  17726.0  Diesel     work      NaN
# 271       ÖST        0,82  46514.0  Diesel   medium  32744.0
# 272      MITT        1,03  56654.0  Diesel      big  26009.0
# 273      MITT        0,82  46814.0  Diesel   medium  32744.0
# 274      MITT        0,45  15494.0  Diesel     work      NaN
# 275       ÖST        0,62  36464.0  Diesel   medium      NaN
# 276       SYD        0,84  47594.0  Diesel      big  26009.0
# 277       SYD        0,63  37454.0  Diesel    small  13543.0
# 278       ÖST        0,77  44114.0  Diesel   medium      NaN
# 279       SYD        0,80  45434.0  Diesel      big  26009.0
# 280      MITT        0,86  48824.0  Diesel   medium  32744.0
# 281      MITT        0,76  43574.0  Diesel   medium  32744.0
#
#                                           new_fuel
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                       Fordonsgas
# 8                                              NaN
# 9                                              NaN
# 10                                       Gasfordon
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                      Fordonsgas
# 16                                             NaN
# 17                         Elfordon skåp. 26.7 kWh
# 18   Biodiesel B25.5 (25% inblandning av FAME/HVO)
# 19                                       Gasfordon
# 20   Biodiesel B25.5 (25% inblandning av FAME/HVO)
# 21                                       Gasfordon
# 22                                       Gasfordon
# 23   Biodiesel B25.5 (25% inblandning av FAME/HVO)
# 24                                             NaN
# 25                                      Fordonsgas
# 26                                             NaN
# 27                                       Gasfordon
# 28                                             NaN
# 29                                             NaN
# ..                                             ...
# 252                                            NaN
# 253                                            NaN
# 254                                            NaN
# 255                                            NaN
# 256                                      Gasfordon
# 257                                            NaN
# 258                        Elfordon skåp. 26.7 kWh
# 259                                      Gasfordon
# 260                                            NaN
# 261                        Elfordon skåp. 26.7 kWh
# 262                                            NaN
# 263                                            NaN
# 264  Biodiesel B25.5 (25% inblandning av FAME/HVO)
# 265                                      Gasfordon
# 266  Biodiesel B25.5 (25% inblandning av FAME/HVO)
# 267                                      Gasfordon
# 268                                            NaN
# 269  Biodiesel B25.5 (25% inblandning av FAME/HVO)
# 270                                            NaN
# 271  Biodiesel B25.5 (25% inblandning av FAME/HVO)
# 272                                      Gasfordon
# 273  Biodiesel B25.5 (25% inblandning av FAME/HVO)
# 274                                            NaN
# 275                                            NaN
# 276                                      Gasfordon
# 277                        Elfordon skåp. 26.7 kWh
# 278                                            NaN
# 279                                      Gasfordon
# 280  Biodiesel B25.5 (25% inblandning av FAME/HVO)
# 281  Biodiesel B25.5 (25% inblandning av FAME/HVO)
#
# [282 rows x 11 columns]

# %%
write_excel(df_scen1, 'scen1')
