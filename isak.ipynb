# %%
# %load_ext blackcellmagic
import pandas as pd
import numpy as np
from itertools import chain
from collections import defaultdict
from sys import exit

# %%
total_csvs = !ls total_*
costs_csvs = !ls kostnader/

# %%
def write_excel(file_name: str, sheets):
    writer = pd.ExcelWriter(f'{file_name}.xlsx')
    [df.to_excel(writer, sheet) for sheet, df in sheets.items()]
    writer.save()

def write_csv(file_name: str, df):
    df.to_csv(file_name)

def read_csv(file_name: str, **args: dict) -> pd.DataFrame:
    return pd.read_csv(filepath_or_buffer=file_name, **args)

def file_name_suffix(name: str) -> str:
    return name[name.rfind('_') + 1:-4]

total_names = ['fuel', 'co2']
df_totals = {
    file_name_suffix(name): read_csv(
        file_name=name, encoding='utf-8', names=total_names, header=0)
    for name in total_csvs
}

df_costs = defaultdict(dict)
for csv in costs_csvs:
    type_, cat = csv[:-4].split('_')
    col = type_ if type_ == 'brand' else f'new_{type_}'
    df = read_csv(file_name=f'kostnader/{csv}', names=[col, 'cost'], header=0)
    if type_ == 'brand':
        df[type_] = df[type_].str.upper()
    df_costs[col][cat] = df
                     
df_new_co2 = read_csv(
    file_name='fordonspark.csv',
    encoding='utf-8',
    header=0,
    names=['license_nbr', 'co2'])
df_cars = pd.read_csv(
    'cars.csv',
    encoding='latin1',
    sep=';',
    header=0,
    names=[
        'license_nbr', 'brand', 'year', 'driver', 'region', 'consumption',
        'co2', 'fuel'
    ])

# %%
df_cars["brand"] = df_cars["brand"].apply(lambda b: " ".join(b.upper().split(" ")[:2]))
df_cars = df_cars.assign(category=[get_car_cat(brand) for brand in df_cars["brand"]])
df_cars["co2"] = df_new_co2["co2"]
df_cars.head()
# Out:
#   license_nbr           brand  year                driver region consumption  \
# 0     YZF 336  VW TRANSPORTER  2018       ALBIN LÖFSTRAND    ÖST        0,62
# 1     PYN 113     MB SPRINTER  2018  ALEXANDER WERNERSSON    SYD        0,81
# 2     JUB 435  VW TRANSPORTER  2016      ANDERS ANDERSSON    SYD        0,77
# 3     YLJ 847     MB SPRINTER  2017        ANDERS BONNIER    SYD        0,81
# 4     YHN 351         AUDI Q5  2017       ANDERS KARLSSON    ÖST        0,59
#
#      co2    fuel category
# 0  36464  Diesel   medium
# 1  45974  Diesel      big
# 2  44114  Diesel   medium
# 3  45974  Diesel      big
# 4  18098  Diesel     work

# %%
df_totals['work']
# Out:
#                                              fuel    co2
# 0                            Konventionell diesel  16365
# 1   Biodiesel B25.5 (25% inblandning av FAME/HVO)  14384
# 2                            Konventionell bensin  15930
# 3               Bensin E4.8 (4.8% bioinblandning)  15875
# 4                                    Etanol (E85)  16836
# 5                                      Fordonsgas  10126
# 6                                Elfordon. 39 kWh  14311
# 7                                Elfordon. 17 kWh  10655
# 8                               Elfordon. 100 kWh  25367
# 9                                      Laddhybrid  12188
# 10                                       Elhybrid  13113

# %%
df_totals['big']
# Out:
#                                             fuel    co2
# 0                           Konventionell diesel  45530
# 1  Biodiesel B25.5 (25% inblandning av FAME/HVO)  37334
# 2                                      Gasfordon  26009

# %%
df_totals['medium']
# Out:
#                                             fuel    co2
# 0                           Konventionell diesel  36418
# 1  Biodiesel B25.5 (25% inblandning av FAME/HVO)  32744

# %%
df_totals['small']
# Out:
#                                             fuel    co2
# 0                           Konventionell diesel  27742
# 1  Biodiesel B25.5 (25% inblandning av FAME/HVO)  23182
# 2                           Konventionell bensin  32822
# 3           Biobensin E4.8 (4.8% bioinblandning)  29587
# 4                        Elfordon skåp. 26.7 kWh  13543
# 5                                      Gasfordon  16951

# %%
car_cats = {
    "service": {
        "small": ["VW CADDY", "VW TRANSPORT"],
        "medium": ["MB VITO", "VW TRANSPORTER"],
        "big": ["MB SPRINTER", "VW CRAFTER"],
    },
    "work": [
        "AUDI A6",
        "AUDI Q5",
        "BMW 220D",
        "BMW 318D",
        "BMW 320D",
        "SKODA SUPERB",
        "VOLVO S60",
        "VOLVO S90",
        "VOLVO V60",
        "VOLVO V90",
        "VOLVO XC40",
        "VOLVO XC60",
        "VOLVO XC70",
        "VW PASSAT",
        "VW TIGUAN",
        "VW TOUAREG",
    ],
}

service_brands = set(chain(*car_cats["service"].values()))
work_brands = set(car_cats["work"])

# %%
BIODIESEL = "Biodiesel B25.5 (25% inblandning av FAME/HVO)"
BIOBENSIN = "Biobensin E4.8 (4.8% bioinblandning)"
DIESEL = "Konventionell diesel"
BENSIN = "Konventionell bensin"
ELFORDON_17 = "Elfordon. 17 kWh"


def scen1_a(totals, df_cars):
    df = df_cars.query(
        "(brand in @service_brands & year < 2015) | (brand in @work_brands & year < 2017)"
    )
    return totals, df


# Remove biodiesel from all
def scen1_b(totals, df_cars):
    d = {}
    _, df_cars = scen1_a(totals, df_cars)
    for cat, df in totals.items():
        remaining = df.drop(
            df[((df["fuel"] == BIODIESEL) | (df["fuel"] == BIOBENSIN))].index
        )
        d[cat] = remaining
    return d, df_cars


def scen1_c(totals, df_cars):
    # Samma som scenario 1, men räkna med svensk elmix.
    elmixes = {
        "small": {"Elfordon skåp. 26.7 kWh": 11656},
        "work": {
            "Elfordon. 39 kWh": 13647,
            "Elfordon. 17 kWh": 9785,
            "Elfordon. 100 kWh": 24366,
            "Laddhybrid": 12031,
        },
    }
    _, df_cars = scen1_a(totals, df_cars)
    for cat, df in totals.items():
        if cat not in elmixes:
            continue
        for fuel, val in elmixes[cat].items():
            df.loc[df['fuel'].str.contains(fuel), 'co2'] = val
    

    return totals, df_cars


def scen1_d(totals, df_cars):
    # Samma som scenario 1, men räkna med europeisk elmix.
    elmixes = {
        "small": {"Elfordon skåp. 26.7 kWh": 21740},
        "work": {
            "Elfordon. 39 kWh": 17194,
            "Elfordon. 17 kWh": 12846,
            "Elfordon. 100 kWh": 29712,
            "Laddhybrid": 15439,
        },
    }
    _, df_cars = scen1_a(totals, df_cars)
    for cat, df in totals.items():
        if cat not in elmixes:
            continue
        for fuel, val in elmixes[cat].items():
            df.loc[df['fuel'].str.contains(fuel), 'co2'] = val
    

    return totals, df_cars


def scen2(totals, df_cars):
    # Byt färre fordon, sätt mängden utbytta fordon till 10% => 28 av 282.
    sorted_cars = df_cars.sort_values(by=['co2'], ascending=False)
    return totals, sorted_cars.iloc[:len(sorted_cars) // 10, :]


def scen3(totals, df_cars):
    d = {}
    _, df_cars = scen1_a(totals, df_cars)
    for cat, df in totals.items():
        d[cat] = df[(df["fuel"] == BENSIN) | (df["fuel"] == DIESEL)]
    return d, df_cars


def scen4(totals, df_cars):
    # Byt samtliga fordon, även om leasingperioden inte utgått, förutsatt att det finns alternativ som har lägre utsläppsvärden. Därmed ej tillämpbart på företaget men ger en mer allmän teoretisk tillämpning.
    return totals, df_cars


def scen5(totals, df_cars):
    pass

def scen6_a(totals, df_cars):
    _, df_cars = scen1_a(totals, df_cars)
    return totals, df_cars

def scen6_b(totals, df_cars):
    _, df_cars = scen1_a(totals, df_cars)
    return totals, df_cars

def copy_df_totals(df_totals):
    d = {}
    for cat, df in df_totals.items():
        d[cat] = df.copy()
    return d

def filter_better_co2(df, cat_co2_dict):
    b = pd.DataFrame()
    for cat, co2 in cat_co2_dict.items():
        a = ((df['category'] == cat) & (df['co2'] > co2))
        b = b.append(df[a == True])
    return b.sort_index()

# Find best fuel value for every category
def find_opt_co2(scen, df_cars, df_totals):
    cat_co2_dict = {}
    co2_fuel_dict = {}
    totals, cars = copy_df_totals(df_totals), df_cars.copy()
    d, df_cars = scen(totals, cars)
    for cat, df in d.items():
        min_idx = df["co2"].idxmin()
        fuel, co2 = df.loc[min_idx].values
        cat_co2_dict[cat] = co2
        co2_fuel_dict[co2] = fuel
    return df_cars, cat_co2_dict, co2_fuel_dict

# %%
def get_car_cat(brand):
    if brand in work_brands:
        return "work"
    for k, v in car_cats["service"].items():
        if brand in set(v):
            return k
    raise Exception(f"Could not classify brand {brand}")


def optimize_big(df, cat_co2_dict):
    # Only replace if medium is better than big
    if cat_co2_dict["big"] < cat_co2_dict["medium"]:
        return df, pd.DataFrame()
    candidates = df.query(
        "category == 'big' & (region == 'ÖST' | region == 'SYD' | region == 'VÄST')"
    ).sort_values("co2", ascending=False)
    candidates = candidates.iloc[:len(candidates) // 4]
    df_replaced = df.copy()
    df_replaced.loc[candidates.index, "category"] = "medium"
    return df_replaced, candidates


def find_best_fuels(df, cat_co2_dict, co2_fuel_dict):
    df = filter_better_co2(df, cat_co2_dict)
    df, big_replaced = optimize_big(df, cat_co2_dict)
    df = df.assign(new_co2=[cat_co2_dict[cat] for cat in df["category"]])
    df = df.assign(new_fuel=[co2_fuel_dict.get(co2, np.nan) for co2 in df["new_co2"]])
    return df, big_replaced

def assign_costs(name, df):
    copy = df.copy()
    for type_, dict_ in df_costs.items():
        for cat, cost_df in dict_.items():
            c = df_costs[type_][cat]
            a = df[(df['category'] == cat)]
            new_col = f'{type_}_cost'
            if new_col == 'new_fuel_cost' and name in cost_scenarios:
                continue
            b = a.join(c.set_index(type_), on=type_)['cost']
            if new_col in copy.columns:
                b = b.rename(new_col)
                copy.update(b)
            else:
                copy = copy.assign(**{new_col:b})
    return copy
            

cost_scenarios = {'scen6_a', 'scen6_b'}
def run_scenarios(scenarios, df_cars, df_totals):
    sheets = {}
    for scen in scenarios:
        name = scen.__name__
        print(name)
        df, big_replaced = find_best_fuels(*find_opt_co2(scen, df_cars, df_totals))
        df = assign_costs(name, df)
        df.loc[big_replaced.index, "category"] = "big"  # Show the 25% cars as big again
        if name in cost_scenarios:
            df = run_cost_scenario(name, df)
        df = df_cars.combine_first(df)
        df = assign_costs(name, df)
        sheets[name] = df
    return sheets
scenarios = [scen1_a, scen1_b, scen1_c, scen1_d, scen2, scen3, scen4, scen6_a, scen6_b]
sheets = run_scenarios(scenarios, df_cars, df_totals)
write_excel("isak",sheets)
# Out:
# scen1_a
# scen1_b
# scen1_c
# scen1_d
# scen2
# scen3
# scen4
# scen6_a
# Int64Index([145, 22, 276, 259, 256, 249], dtype='int64')
# scen6_b
# Int64Index([145, 22, 276, 259, 256, 249], dtype='int64')

# %%
def fuel_to_co2():
    d = defaultdict(dict)
    for cat, df in df_totals.items():
        for index, row in df.iterrows():
            d[cat][row['fuel']] = row['co2']
    return d
    
def scen6_a_fuel_costs(fuel_dict):
    return fuel_dict


def scen6_b_fuel_costs(fuel_dict):
    d = {}
    for cat, df in fuel_dict.items():
        d[cat] = df[df["new_fuel"] != ELFORDON_17]
    return d

def min_fuel_cost(df):
    min_idx = df['cost'].idxmin()
    return df.iloc[min_idx]
    

def run_cost_scenario(scen, df):
    fuel_co2_dict = fuel_to_co2()
    copy = df.copy()
    copy.loc[:, 'new_fuel_cost'] = None
    fuel_dict = globals()[f'{scen}_fuel_costs'](df_costs['new_fuel'])
    for cat, df_cost in fuel_dict.items():
        min_fuel, min_val = min_fuel_cost(df_cost)
        if cat == 'big':
            f2, c2 = min_fuel_cost(fuel_dict['medium'])
            if c2 < min_val:
                top25 = copy[(copy['category'] == 'big') & (copy['brand_cost'] > c2) & ((copy['region'] == 'SYD') | (copy['region'] == 'VÄST') | (copy['region'] == 'ÖST'))].sort_values("brand_cost", ascending=False)
                top25 = top25.iloc[:len(top25) // 4].index
                display(top25)
                rest = copy[(copy['category'] == cat) & (copy['brand_cost'] > min_val)].index
                copy.loc[rest, 'new_fuel_cost'] = min_val
                copy.loc[top25, 'new_fuel_cost'] = c2
                copy.loc[rest, 'new_cost_fuel'] = min_fuel
                copy.loc[top25, 'new_cost_fuel'] = f2
                copy.loc[rest, 'new_cost_fuel_co2'] = fuel_co2_dict[cat][min_fuel]
                copy.loc[top25, 'new_cost_fuel_co2'] = fuel_co2_dict[cat][f2]
        else:
            a = copy[(copy['category'] == cat) & (copy['brand_cost'] > min_val)]
            copy.loc[a.index, 'new_fuel_cost'] = min_val
            copy.loc[a.index, 'new_cost_fuel'] = min_fuel
            copy.loc[a.index, 'new_cost_fuel_co2'] = fuel_co2_dict[cat][min_fuel]
    return copy

# %%
sheets['scen6_a']
# Out:
#               brand   brand_cost category    co2 consumption  \
# 0    VW TRANSPORTER  505950.0819   medium  36464        0,62
# 1       MB SPRINTER  617705.9583      big  45974        0,81
# 2    VW TRANSPORTER  505950.0819   medium  44114        0,77
# 3       MB SPRINTER  617705.9583      big  45974        0,81
# 4           AUDI Q5  324389.5201     work  18098        0,59
# 5          VW CADDY  373639.8450    small  31034        0,50
# 6        VW CRAFTER  581278.3881      big  47444        0,84
# 7          BMW 320D  303905.6001     work  15866        0,47
# 8          BMW 320D  303905.6001     work  15278        0,44
# 9        VW CRAFTER  581278.3881      big  47444        0,84
# 10       VW CRAFTER  581278.3881      big  48374        0,86
# 11       VW CRAFTER  581278.3881      big  47444        0,84
# 12          AUDI A6  242926.6983     work  15434        0,45
# 13       VW CRAFTER  581278.3881      big  45974        0,81
# 14     VW TRANSPORT  371634.4266    small  30884        0,50
# 15        VW PASSAT  294876.3345     work  14630        0,41
# 16   VW TRANSPORTER  505950.0819   medium  36464        0,62
# 17         VW CADDY  373639.8450    small  36914        0,62
# 18   VW TRANSPORTER  505950.0819   medium  43184        0,75
# 19       VW CRAFTER  581278.3881      big  48374        0,86
# 20   VW TRANSPORTER  505950.0819   medium  46124        0,81
# 21       VW CRAFTER  581278.3881      big  48374        0,86
# 22      MB SPRINTER  617705.9583      big  46664        0,82
# 23   VW TRANSPORTER  505950.0819   medium  46514        0,82
# 24       VW CRAFTER  581278.3881      big  43964        0,77
# 25       VOLVO XC60  324963.9198     work  17726        0,57
# 26      MB SPRINTER  617705.9583      big  45974        0,81
# 27      MB SPRINTER  617705.9583      big  46664        0,82
# 28          MB VITO  544394.7103   medium  38624        0,66
# 29       VOLVO XC40  326688.9931     work  16514        0,50
# ..              ...          ...      ...    ...         ...
# 252       VOLVO V60  307233.7388     work  17726        0,57
# 253      VW TOUAREG  337255.7066     work  19706        0,67
# 254    VW TRANSPORT  371634.4266    small  31034        0,50
# 255  VW TRANSPORTER  505950.0819   medium  36464        0,62
# 256     MB SPRINTER  617705.9583      big  45434        0,80
# 257  VW TRANSPORTER  505950.0819   medium  36464        0,62
# 258        VW CADDY  373639.8450    small  34214        0,57
# 259     MB SPRINTER  617705.9583      big  45434        0,80
# 260     MB SPRINTER  617705.9583      big  45284        0,80
# 261        VW CADDY  373639.8450    small  34214        0,57
# 262      VOLVO XC60  324963.9198     work  17726        0,57
# 263     MB SPRINTER  617705.9583      big  46514        0,82
# 264  VW TRANSPORTER  505950.0819   medium  46514        0,82
# 265      VW CRAFTER  581278.3881      big  45974        0,81
# 266         MB VITO  544394.7103   medium  43184        0,75
# 267     MB SPRINTER  617705.9583      big  46664        0,82
# 268      VW CRAFTER  581278.3881      big  47444        0,84
# 269         MB VITO  544394.7103   medium  46514        0,82
# 270      VOLVO XC60  324963.9198     work  17726        0,57
# 271  VW TRANSPORTER  505950.0819   medium  46514        0,82
# 272      VW CRAFTER  581278.3881      big  56654        1,03
# 273         MB VITO  544394.7103   medium  46814        0,82
# 274       VOLVO V90  317744.1710     work  15494        0,45
# 275  VW TRANSPORTER  505950.0819   medium  36464        0,62
# 276     MB SPRINTER  617705.9583      big  47594        0,84
# 277        VW CADDY  373639.8450    small  37454        0,63
# 278  VW TRANSPORTER  505950.0819   medium  44114        0,77
# 279     MB SPRINTER  617705.9583      big  45434        0,80
# 280         MB VITO  544394.7103   medium  48824        0,86
# 281         MB VITO  544394.7103   medium  43574        0,76
#
#                                driver    fuel license_nbr  new_co2  \
# 0                     ALBIN LÖFSTRAND  Diesel     YZF 336      NaN
# 1                ALEXANDER WERNERSSON  Diesel     PYN 113      NaN
# 2                    ANDERS ANDERSSON  Diesel     JUB 435      NaN
# 3                      ANDERS BONNIER  Diesel     YLJ 847      NaN
# 4                     ANDERS KARLSSON  Diesel     YHN 351      NaN
# 5                      ANDERS NILSSON  Diesel     BAP 210      NaN
# 6                    ANDREAS ENGSTRÖM  Diesel     RSA 761      NaN
# 7                     ANDREAS FRITZON  Diesel     YHR 669  10126.0
# 8                 ANDREAS KNUTSEN-ÖY   Diesel     EFM 275      NaN
# 9                        ANDREAS LÖÖV  Diesel     ELW 214      NaN
# 10                   ANDREAS SVENSSON  Diesel     LXL 304  26009.0
# 11                   ANDREAS TAGESSON  Diesel     CCO 411      NaN
# 12                         ANNA OLSÉN  Diesel     YOU 925      NaN
# 13                      ANTON LINDAHL  Diesel     CJJ 645      NaN
# 14                        ARI HARJULA  Diesel     YZH 793      NaN
# 15                    AULIS GÅRDEMARK  Diesel     ENC 746  10126.0
# 16                   BASHAR ALGAILANI  Diesel     YYL 602      NaN
# 17                  BEG-CENTER ÖREBRO  Diesel     NRR 764  13543.0
# 18                    BENGT BERGSTRÖM  Diesel     EDD 689  32744.0
# 19                      BENNY OLANDER  Diesel     MBM 295  26009.0
# 20                     BILLY GRANBERG  Diesel     OSF 296  32744.0
# 21                      BJÖRN PERSSON  Diesel     PYT 177  26009.0
# 22                   CHRISTER LARSSON  Diesel     PXA 837  26009.0
# 23                  CHRISTIAN SANDHÉN  Diesel     SPO 579  32744.0
# 24              CHRISTOFFER DANDANELL  Diesel     ZDG 643      NaN
# 25              CHRISTOFFER JANNESSON  Diesel     YAJ 341  10126.0
# 26                  CHRISTOFFER STEEN  Diesel     YLJ 848      NaN
# 27                      CLAES WINGREN  Diesel     MEH 907  26009.0
# 28                        CONNY GRAHN  Diesel     JWP 114      NaN
# 29                       DAN JONASSON  Diesel     MLU 460      NaN
# ..                                ...     ...         ...      ...
# 252                    THOMAS EDSTRÖM  Diesel     YXT 676      NaN
# 253                     THOMAS HASCHE  Diesel     HHN 846      NaN
# 254                     THOMAS KNUTER  Diesel     PZG 035      NaN
# 255                     TOBIAS JENSEN  Diesel     YLK 178      NaN
# 256                  TOBIAS PETERSSON  Diesel     APF 478  26009.0
# 257                      TOM SÖRENSEN  Diesel     PEY 536      NaN
# 258                    TOMAS ARONSSON  Diesel     NKW 765  13543.0
# 259                    TOMAS CARLSSON  Diesel     JMD 187  26009.0
# 260                     TOMAS PERSSON  Diesel     JFH 066      NaN
# 261                     TOMAS ÅKESSON  Diesel     GOY 021  13543.0
# 262                         TOMM HOLM  Diesel     PFZ 985      NaN
# 263                      TOMMY HANSEN  Diesel     ZDE 122      NaN
# 264                        TOMMY ROVA  Diesel     UUS 364  32744.0
# 265                    TOMMY SVENSSON  Diesel     GOA 490  26009.0
# 266                  TONIE ARTHURSSON  Diesel     HOH 068  32744.0
# 267                      TONY OHLSSON  Diesel     MSF 003  26009.0
# 268                 TORBJÖRN CARLSSON  Diesel     NBA 820      NaN
# 269                  TORBJÖRN OLANDER  Diesel     NWJ 120  32744.0
# 270                     TORE MATTSSON  Diesel     YKS 258      NaN
# 271                    TORGNY AHLSTEN  Diesel     PNU 681  32744.0
# 272     UDDEHOLM, HAGFORS 1 (OLA ASP)  Diesel     JSH 364  26009.0
# 273  UDDEHOLM, HAGFORS 2 (J Emilsson)  Diesel     CNN 077  32744.0
# 274                    ULF PETTERSSON  Diesel     EYP 932      NaN
# 275                     URBAN JONSSON  Diesel     YYL 598      NaN
# 276      VCC Olofström (J-Å Sjöstedt)  Diesel     ACC 598  26009.0
# 277      VCC Olofström (J-Å Sjöstedt)  Diesel     GTU 734  13543.0
# 278           VERKSTADSBIL ROSERSBERG  Diesel     HCU 385      NaN
# 279                  VICTOR HÅKANSSON  Diesel     MWS 882  26009.0
# 280    VPT 1, SKÖVDE (TOMAS ARONSSON)  Diesel     KZC 239  32744.0
# 281      VPT, SKÖVDE (TOMAS ARONSSON)  Diesel     MEJ 398  32744.0
#
#                new_cost_fuel  new_cost_fuel_co2  \
# 0                        NaN                NaN
# 1                        NaN                NaN
# 2                        NaN                NaN
# 3                        NaN                NaN
# 4                        NaN                NaN
# 5                        NaN                NaN
# 6                        NaN                NaN
# 7           Elfordon. 17 kWh            10655.0
# 8                        NaN                NaN
# 9                        NaN                NaN
# 10                       NaN                NaN
# 11                       NaN                NaN
# 12                       NaN                NaN
# 13                       NaN                NaN
# 14                       NaN                NaN
# 15          Elfordon. 17 kWh            10655.0
# 16                       NaN                NaN
# 17   Elfordon skåp. 26.7 kWh            13543.0
# 18      Konventionell diesel            36418.0
# 19                       NaN                NaN
# 20      Konventionell diesel            36418.0
# 21                       NaN                NaN
# 22      Konventionell diesel            45530.0
# 23      Konventionell diesel            36418.0
# 24                       NaN                NaN
# 25          Elfordon. 17 kWh            10655.0
# 26                       NaN                NaN
# 27      Konventionell diesel            45530.0
# 28                       NaN                NaN
# 29                       NaN                NaN
# ..                       ...                ...
# 252                      NaN                NaN
# 253                      NaN                NaN
# 254                      NaN                NaN
# 255                      NaN                NaN
# 256     Konventionell diesel            45530.0
# 257                      NaN                NaN
# 258  Elfordon skåp. 26.7 kWh            13543.0
# 259     Konventionell diesel            45530.0
# 260                      NaN                NaN
# 261  Elfordon skåp. 26.7 kWh            13543.0
# 262                      NaN                NaN
# 263                      NaN                NaN
# 264     Konventionell diesel            36418.0
# 265                      NaN                NaN
# 266     Konventionell diesel            36418.0
# 267     Konventionell diesel            45530.0
# 268                      NaN                NaN
# 269     Konventionell diesel            36418.0
# 270                      NaN                NaN
# 271     Konventionell diesel            36418.0
# 272                      NaN                NaN
# 273     Konventionell diesel            36418.0
# 274                      NaN                NaN
# 275                      NaN                NaN
# 276     Konventionell diesel            45530.0
# 277  Elfordon skåp. 26.7 kWh            13543.0
# 278                      NaN                NaN
# 279     Konventionell diesel            45530.0
# 280     Konventionell diesel            36418.0
# 281     Konventionell diesel            36418.0
#
#                                           new_fuel  new_fuel_cost    region  \
# 0                                              NaN            NaN       ÖST
# 1                                              NaN            NaN       SYD
# 2                                              NaN            NaN       SYD
# 3                                              NaN            NaN       SYD
# 4                                              NaN            NaN       ÖST
# 5                                              NaN            NaN       SYD
# 6                                              NaN            NaN       ÖST
# 7                                       Fordonsgas    137677.8936      MITT
# 8                                              NaN            NaN      MITT
# 9                                              NaN            NaN      MITT
# 10                                       Gasfordon            NaN      MITT
# 11                                             NaN            NaN       ÖST
# 12                                             NaN            NaN  CENTRALT
# 13                                             NaN            NaN      MITT
# 14                                             NaN            NaN       ÖST
# 15                                      Fordonsgas    137677.8936  CENTRALT
# 16                                             NaN            NaN       ÖST
# 17                         Elfordon skåp. 26.7 kWh    308034.6369  CENTRALT
# 18   Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296  CENTRALT
# 19                                       Gasfordon            NaN      VÄST
# 20   Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296      MITT
# 21                                       Gasfordon            NaN      MITT
# 22                                       Gasfordon    469797.3296       SYD
# 23   Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296       ÖST
# 24                                             NaN            NaN       ÖST
# 25                                      Fordonsgas    137677.8936      VÄST
# 26                                             NaN            NaN       SYD
# 27                                       Gasfordon    583084.0000       SYD
# 28                                             NaN            NaN      MITT
# 29                                             NaN            NaN      VÄST
# ..                                             ...            ...       ...
# 252                                            NaN            NaN       SYD
# 253                                            NaN            NaN  CENTRALT
# 254                                            NaN            NaN       ÖST
# 255                                            NaN            NaN       SYD
# 256                                      Gasfordon    469797.3296       SYD
# 257                                            NaN            NaN       ÖST
# 258                        Elfordon skåp. 26.7 kWh    308034.6369      MITT
# 259                                      Gasfordon    469797.3296      VÄST
# 260                                            NaN            NaN      MITT
# 261                        Elfordon skåp. 26.7 kWh    308034.6369       ÖST
# 262                                            NaN            NaN      MITT
# 263                                            NaN            NaN       SYD
# 264  Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296       ÖST
# 265                                      Gasfordon            NaN      MITT
# 266  Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296      MITT
# 267                                      Gasfordon    583084.0000      MITT
# 268                                            NaN            NaN       ÖST
# 269  Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296      MITT
# 270                                            NaN            NaN       ÖST
# 271  Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296       ÖST
# 272                                      Gasfordon            NaN      MITT
# 273  Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296      MITT
# 274                                            NaN            NaN      MITT
# 275                                            NaN            NaN       ÖST
# 276                                      Gasfordon    469797.3296       SYD
# 277                        Elfordon skåp. 26.7 kWh    308034.6369       SYD
# 278                                            NaN            NaN       ÖST
# 279                                      Gasfordon    583084.0000       SYD
# 280  Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296      MITT
# 281  Biodiesel B25.5 (25% inblandning av FAME/HVO)    469797.3296      MITT
#
#      year
# 0    2018
# 1    2018
# 2    2016
# 3    2017
# 4    2017
# 5    2017
# 6    2015
# 7    2016
# 8    2017
# 9    2016
# 10   2012
# 11   2016
# 12   2018
# 13   2016
# 14   2018
# 15   2015
# 16   2018
# 17   2009
# 18   2014
# 19   2012
# 20   2014
# 21   2012
# 22   2013
# 23   2013
# 24   2018
# 25   2015
# 26   2017
# 27   2012
# 28   2015
# 29   2018
# ..    ...
# 252  2018
# 253  2018
# 254  2017
# 255  2017
# 256  2014
# 257  2017
# 258  2014
# 259  2014
# 260  2018
# 261  2013
# 262  2017
# 263  2018
# 264  2014
# 265  2013
# 266  2012
# 267  2013
# 268  2015
# 269  2013
# 270  2017
# 271  2014
# 272  2009
# 273  2008
# 274  2017
# 275  2018
# 276  2011
# 277  2008
# 278  2015
# 279  2014
# 280  2010
# 281  2012
#
# [282 rows x 15 columns]
