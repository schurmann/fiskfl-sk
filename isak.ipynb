# %%
# %load_ext blackcellmagic
import pandas as pd
import numpy as np
from itertools import chain
from math import floor
# Out:
# The blackcellmagic extension is already loaded. To reload it, use:
#   %reload_ext blackcellmagic

# %%
total_csvs = !ls total_*

# %%
def write_excel(file_name: str, dfs, sheets):
    writer = pd.ExcelWriter(f'{file_name}.xlsx')
    [df.to_excel(writer, sheet) for df, sheet in zip(dfs, sheets)]
    writer.save()


def read_csv(file_name: str, **args: dict) -> pd.DataFrame:
    return pd.read_csv(filepath_or_buffer=file_name, **args)


def file_name_suffix(name: str) -> str:
    return name[name.rfind('_') + 1:-4]


total_names = ['fuel', 'co2']
df_totals = {
    file_name_suffix(name): read_csv(
        file_name=name, encoding='utf-8', names=total_names, header=0)
    for name in total_csvs
}
df_new_co2 = read_csv(
    file_name='fordonspark.csv',
    encoding='utf-8',
    header=0,
    names=['license_nbr', 'co2'])
df_cars = pd.read_csv(
    'cars.csv',
    encoding='latin1',
    sep=';',
    header=0,
    names=[
        'license_nbr', 'brand', 'year', 'driver', 'region', 'consumption',
        'co2', 'fuel'
    ])
df_cars.head(20)
# Out:
#    license_nbr                                     brand  year  \
# 0      YZF 336                           VW TRANSPORTER   2018
# 1      PYN 113                               MB SPRINTER  2018
# 2      JUB 435                    VW TRANSPORTER SKÅP T6  2016
# 3      YLJ 847                  MB SPRINTER 316 CDI SKÅP  2017
# 4      YHN 351                       AUDI Q5 2.0 QUATTRO  2017
# 5      BAP 210                        VW CADDY MAXI SKÅP  2017
# 6      RSA 761              VW TRANSPORT CRAFTER SKÅP 35  2015
# 7      YHR 669                           BMW 320D XDRIVE  2016
# 8      EFM 275  BMW 320D SEDAN BUSINESS ADVATAGE EDITION  2017
# 9      ELW 214                   VW TRANSPORT CRAFTER 37  2016
# 10     LXL 304              VW TRANSPORT CRAFTER 35 SKÅP  2012
# 11     CCO 411              VW TRANSPORT CRAFTER 35 SKÅP  2016
# 12     YOU 925                                   AUDI A6  2018
# 13     CJJ 645                   VW TRANSPORT CRAFTER 36  2016
# 14     YZH 793                        VW TRANSPORT CADDY  2018
# 15     ENC 746              VW PASSAT SC TDI 150 MASTERS  2015
# 16     YYL 602                            VW TRANSPORTER  2018
# 17     NRR 764                        VW CADDY MAXI SKÅP  2009
# 18     EDD 689                    VW TRANSPORTER SKÅP T5  2014
# 19     MBM 295              VW TRANSPORT CRAFTER 35 SKÅP  2012
#
#                   driver    region consumption  co2    fuel
# 0        ALBIN LÖFSTRAND       ÖST        0,62  161  Diesel
# 1   ALEXANDER WERNERSSON       SYD        0,81  213  Diesel
# 2       ANDERS ANDERSSON       SYD        0,77  203  Diesel
# 3         ANDERS BONNIER       SYD        0,81  213  Diesel
# 4        ANDERS KARLSSON       ÖST        0,59  154  Diesel
# 5         ANDERS NILSSON       SYD        0,50  132  Diesel
# 6       ANDREAS ENGSTRÖM       ÖST        0,84  221  Diesel
# 7        ANDREAS FRITZON      MITT        0,47  124  Diesel
# 8    ANDREAS KNUTSEN-ÖY       MITT        0,44  116  Diesel
# 9           ANDREAS LÖÖV      MITT        0,84  221  Diesel
# 10      ANDREAS SVENSSON      MITT        0,86  226  Diesel
# 11      ANDREAS TAGESSON       ÖST        0,84  221  Diesel
# 12            ANNA OLSÉN  CENTRALT        0,45  118  Diesel
# 13         ANTON LINDAHL      MITT        0,81  213  Diesel
# 14           ARI HARJULA       ÖST        0,50  131  Diesel
# 15       AULIS GÅRDEMARK  CENTRALT        0,41  107  Diesel
# 16      BASHAR ALGAILANI       ÖST        0,62  161  Diesel
# 17     BEG-CENTER ÖREBRO  CENTRALT        0,62  164  Diesel
# 18       BENGT BERGSTRÖM  CENTRALT        0,75  198  Diesel
# 19         BENNY OLANDER      VÄST        0,86  226  Diesel

# %%
df_cars["brand"] = df_cars["brand"].apply(lambda b: " ".join(b.upper().split(" ")[:2]))
df_cars["co2"] = df_new_co2["co2"]
df_cars.head()
# Out:
#   license_nbr           brand  year                driver region consumption  \
# 0     YZF 336  VW TRANSPORTER  2018       ALBIN LÖFSTRAND    ÖST        0,62
# 1     PYN 113     MB SPRINTER  2018  ALEXANDER WERNERSSON    SYD        0,81
# 2     JUB 435  VW TRANSPORTER  2016      ANDERS ANDERSSON    SYD        0,77
# 3     YLJ 847     MB SPRINTER  2017        ANDERS BONNIER    SYD        0,81
# 4     YHN 351         AUDI Q5  2017       ANDERS KARLSSON    ÖST        0,59
#
#      co2    fuel
# 0  36464  Diesel
# 1  45974  Diesel
# 2  44114  Diesel
# 3  45974  Diesel
# 4  18098  Diesel

# %%
df_totals['work']
# Out:
#                                              fuel    co2
# 0                            Konventionell diesel  16365
# 1   Biodiesel B25.5 (25% inblandning av FAME/HVO)  14384
# 2                            Konventionell bensin  15930
# 3               Bensin E4.8 (4.8% bioinblandning)  15875
# 4                                    Etanol (E85)  16836
# 5                                      Fordonsgas  10126
# 6                                Elfordon. 39 kWh  14311
# 7                                Elfordon. 17 kWh  10358
# 8                               Elfordon. 100 kWh  25367
# 9                                      Laddhybrid  12188
# 10                                       Elhybrid  13113

# %%
df_totals['big']
# Out:
#                                             fuel    co2
# 0                           Konventionell diesel  45530
# 1  Biodiesel B25.5 (25% inblandning av FAME/HVO)  37334
# 2                                      Gasfordon  26009

# %%
df_totals['medium']
# Out:
#                                             fuel    co2
# 0                           Konventionell diesel  36418
# 1  Biodiesel B25.5 (25% inblandning av FAME/HVO)  32744
# 2                           Konventionell bensin  37787
# 3           Biobensin E4.8 (4.8% bioinblandning)  34988

# %%
df_totals['small']
# Out:
#                                             fuel    co2
# 0                           Konventionell diesel  27742
# 1  Biodiesel B25.5 (25% inblandning av FAME/HVO)  23182
# 2                           Konventionell bensin  32822
# 3           Biobensin E4.8 (4.8% bioinblandning)  29587
# 4                        Elfordon skåp. 26.7 kWh  13543
# 5                                      Gasfordon  16951

# %%
car_cats = {
    "service": {
        "small": ["VW CADDY"],
        "medium": ["MB VITO", "VW TRANSPORTER"],
        "big": ["MB SPRINTER", "VW TRANSPORT"],
    },
    "work": [
        "AUDI A6",
        "AUDI Q5",
        "BMW 220D",
        "BMW 318D",
        "BMW 320D",
        "SKODA SUPERB",
        "VOLVO S60",
        "VOLVO S90",
        "VOLVO V60",
        "VOLVO V90",
        "VOLVO XC40",
        "VOLVO XC60",
        "VOLVO XC70",
        "VW PASSAT",
        "VW TIGUAN",
        "VW TOUAREG",
    ],
}

service_brands = set(chain(*car_cats["service"].values()))
work_brands = set(car_cats["work"])

# %%
BIODIESEL = "Biodiesel B25.5 (25% inblandning av FAME/HVO)"
DIESEL = "Konventionell diesel"
BENSIN = "Konventionell bensin"

def scen_1a(totals, df_cars):
    df = df_cars.query(
        "(brand in @service_brands & year < 2015) | (brand in @work_brands & year < 2017)"
    )
    return totals, df


# Remove biodiesel from all
def scen_1b(totals, df_cars):
    d = {}
    _, df_cars = scen_1a(totals, df_cars)
    for cat, df in totals.items():
        dropped = df.drop(df[df["fuel"] == BIODIESEL].index)
        d[cat] = dropped
    return d, df_cars


def scen_1c(totals, df_cars):
    # Samma som scenario 1, men räkna med svensk elmix.
    pass


def scen_1d(totals, df_cars):
    # Samma som scenario 1, men räkna med europeisk elmix.
    pass


def scen_2(totals, df_cars):
    # Byt färre fordon, de som vars leasingperiod har utgått, sätt mängden utbytta fordon till 10% => 28 av 282.
    pass


def scen3(totals, df_cars):
    d = {}
    for cat, df in totals.items():
        rng = df[(df['fuel'] != BENSIN) & (df['fuel'] != DIESEL)]
        dropped = df.drop(rng.index)
        d[cat] = dropped
    return d, df_cars


def scen4(totals, df_cars):
    # Byt samtliga fordon, även om leasingperioden inte utgått, förutsatt att det finns alternativ som har lägre utsläppsvärden. Därmed ej tillämpbart på företaget men ger en mer allmän teoretisk tillämpning.
    pass


def scen5(totals, df_cars):
    pass


# Find best fuel value for every category
def find_opt_co2(get_scen, totals, df_cars):
    cat_co2_dict = {}
    co2_fuel_dict = {}
    d, df_cars = get_scen(totals, df_cars)
    for cat, df in d.items():
        min_idx = df["co2"].idxmin()
        fuel, co2 = df.loc[min_idx].values
        cat_co2_dict[cat] = co2
        co2_fuel_dict[co2] = fuel
    return df_cars, cat_co2_dict, co2_fuel_dict

# %%
def get_car_cat(brand):
    if brand in work_brands:
        return "work"
    for k, v in car_cats["service"].items():
        if brand in set(v):
            return k
    raise Exception(f"Could not classify brand {brand}")


def optimize_big(df, cat_co2_dict):
    # Only replace if medium is better than big
    if cat_co2_dict["big"] < cat_co2_dict["medium"]:
        return df, pd.DataFrame()
    candidates = df.query(
        "category == 'big' & (region == 'ÖST' | region == 'SYD' | region == 'VÄST')"
    ).sort_values("co2", ascending=False)
    candidates = candidates.loc[: floor(len(candidates) * 0.25)]
    df_replaced = df.copy()
    df_replaced.loc[candidates.index, "category"] = "medium"
    return df_replaced, candidates


def find_best_fuels(df, cat_co2_dict, co2_fuel_dict):
    df = df.assign(category=[get_car_cat(brand) for brand in df["brand"]])
    df, big_replaced = optimize_big(df, cat_co2_dict)
    df = df.assign(new_co2=[cat_co2_dict[cat] for cat in df["category"]])
    df.loc[big_replaced.index, "category"] = "big"  # Show the 25% cars as big again
    df = df.assign(new_fuel=[co2_fuel_dict.get(co2, np.nan) for co2 in df["new_co2"]])
    return df


def run_scenarios(scenarios, df_cars):
    dfs, sheets = [], []
    for scen in scenarios:
        df_final = find_best_fuels(*find_opt_co2(scen, df_totals, df_cars))
        df = df_cars.combine_first(df_final)
        df = df.assign(category=[get_car_cat(brand) for brand in df["brand"]])
        dfs.append(df)
        sheets.append(scen.__name__)
    return dfs, sheets


scenarios = [scen_1a, scen_1b, scen3]
dfs, sheets = run_scenarios(scenarios, df_cars)
write_excel("isak", dfs, sheets)
display(dfs[0])
# Out:
#               brand category    co2 consumption  \
# 0    VW TRANSPORTER   medium  36464        0,62
# 1       MB SPRINTER      big  45974        0,81
# 2    VW TRANSPORTER   medium  44114        0,77
# 3       MB SPRINTER      big  45974        0,81
# 4           AUDI Q5     work  18098        0,59
# 5          VW CADDY    small  31034        0,50
# 6      VW TRANSPORT      big  47444        0,84
# 7          BMW 320D     work  15866        0,47
# 8          BMW 320D     work  15278        0,44
# 9      VW TRANSPORT      big  47444        0,84
# 10     VW TRANSPORT      big  48374        0,86
# 11     VW TRANSPORT      big  47444        0,84
# 12          AUDI A6     work  15434        0,45
# 13     VW TRANSPORT      big  45974        0,81
# 14     VW TRANSPORT      big  30884        0,50
# 15        VW PASSAT     work  14630        0,41
# 16   VW TRANSPORTER   medium  36464        0,62
# 17         VW CADDY    small  36914        0,62
# 18   VW TRANSPORTER   medium  43184        0,75
# 19     VW TRANSPORT      big  48374        0,86
# 20   VW TRANSPORTER   medium  46124        0,81
# 21     VW TRANSPORT      big  48374        0,86
# 22      MB SPRINTER      big  46664        0,82
# 23   VW TRANSPORTER   medium  46514        0,82
# 24     VW TRANSPORT      big  43964        0,77
# 25       VOLVO XC60     work  17726        0,57
# 26      MB SPRINTER      big  45974        0,81
# 27      MB SPRINTER      big  46664        0,82
# 28          MB VITO   medium  38624        0,66
# 29       VOLVO XC40     work  16514        0,50
# ..              ...      ...    ...         ...
# 252       VOLVO V60     work  17726        0,57
# 253      VW TOUAREG     work  19706        0,67
# 254    VW TRANSPORT      big  31034        0,50
# 255  VW TRANSPORTER   medium  36464        0,62
# 256     MB SPRINTER      big  45434        0,80
# 257  VW TRANSPORTER   medium  36464        0,62
# 258        VW CADDY    small  34214        0,57
# 259     MB SPRINTER      big  45434        0,80
# 260     MB SPRINTER      big  45284        0,80
# 261        VW CADDY    small  34214        0,57
# 262      VOLVO XC60     work  17726        0,57
# 263     MB SPRINTER      big  46514        0,82
# 264  VW TRANSPORTER   medium  46514        0,82
# 265    VW TRANSPORT      big  45974        0,81
# 266         MB VITO   medium  43184        0,75
# 267     MB SPRINTER      big  46664        0,82
# 268    VW TRANSPORT      big  47444        0,84
# 269         MB VITO   medium  46514        0,82
# 270      VOLVO XC60     work  17726        0,57
# 271  VW TRANSPORTER   medium  46514        0,82
# 272    VW TRANSPORT      big  56654        1,03
# 273         MB VITO   medium  46814        0,82
# 274       VOLVO V90     work  15494        0,45
# 275  VW TRANSPORTER   medium  36464        0,62
# 276     MB SPRINTER      big  47594        0,84
# 277        VW CADDY    small  37454        0,63
# 278  VW TRANSPORTER   medium  44114        0,77
# 279     MB SPRINTER      big  45434        0,80
# 280         MB VITO   medium  48824        0,86
# 281         MB VITO   medium  43574        0,76
#
#                                driver    fuel license_nbr  new_co2  \
# 0                     ALBIN LÖFSTRAND  Diesel     YZF 336      NaN
# 1                ALEXANDER WERNERSSON  Diesel     PYN 113      NaN
# 2                    ANDERS ANDERSSON  Diesel     JUB 435      NaN
# 3                      ANDERS BONNIER  Diesel     YLJ 847      NaN
# 4                     ANDERS KARLSSON  Diesel     YHN 351      NaN
# 5                      ANDERS NILSSON  Diesel     BAP 210      NaN
